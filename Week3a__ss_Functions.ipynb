# %% [markdown]
# <a href="https://colab.research.google.com/github/sheffieldcl/NIHL-Training/blob/Python-Training/Week3a__ss_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Sequences and Functions

# %% [markdown]
# ## Sequences

# %% [markdown]
# ### Built-in Sequence Functions

# %% [markdown]
# #### enumerate

# %%
collection_obj = [2,4,8,16,32]
i = 0
for value in collection_obj:
    # do something with value
    i += 1
    print('index: {0} --> value: {1}'.format(i, value))

# %%
collection_obj = [2,4,8,16,32]
for i, value in enumerate(collection_obj):
    # do something with value
    print('index: {0} --> value: {1}'.format(i, value))

# %%
some_list = ['foo', 'bar', 'got']
mapping = {}
for i, v in enumerate(some_list):
    mapping[v] = i
mapping

# %% [markdown]
# #### sorted

# %%
sorted([7, 1, 2, 6, 0, 3, 2])

# %%
sorted('horse race')

# %% [markdown]
# #### zip

# %%
seq1 = ['foo', 'bar', 'got']
seq2 = ['one', 'two', 'three']
zipped = zip(seq1, seq2)
list(zipped)

# %%
seq3 = [False, True]
list(zip(seq1, seq2, seq3))

# %%
for i, (a, b) in enumerate(zip(seq1, seq2)):
    print('{0}: {1}, {2}'.format(i, a, b))

# %%
pitchers = [('Nolan', 'Ryan'), ('Roger', 'Clemens'), ('Schilling', 'Curt')]
first_names, last_names = zip(*pitchers) # unzip
first_names

# %%
last_names

# %% [markdown]
# #### reversed

# %%
list(reversed(range(10)))

# %% [markdown]
# #### Creating dicts from sequences

# %%
key_list = [1,2,3]
value_list = ['one','two','three']
mapping = {}
for key, value in zip(key_list, value_list):
    mapping[key] = value
mapping

# %%
mapping = dict(zip(range(5), reversed(range(5))))
mapping

# %% [markdown]
# #### Default values

# %%
some_dict = {1: 'one', 2: 'two', 3: 'three'}

# %%
key = 2
if key in some_dict:
    value = some_dict[key]
else:
    value = 'default_value'
value

# %%
key = 3
value = some_dict.get(key, 'default_value')
value

# %%
words = ['apple', 'bat', 'bar', 'atom', 'book']
by_letter = {}
for word in words:
    letter = word[0]
    if letter not in by_letter:
        by_letter[letter] = [word]
    else:
        by_letter[letter].append(word)
by_letter

# %%
by_letter = {}
for word in words:
    letter = word[0]
    by_letter.setdefault(letter, []).append(word)
by_letter

# %%
by_letter = {}
from collections import defaultdict
by_letter = defaultdict(list)
for word in words:
    by_letter[word[0]].append(word)
by_letter

# %% [markdown]
# ### List, Set, and Dict Comprehensions

# %% [markdown]
# ```python
# result = [expr for val in collection if condition]
# ```

# %% [markdown]
# ```python
# result = []
# for val in collection:
#     if condition:
#         result.append(expr)
# ```

# %%
strings = ['a', 'as', 'bat', 'car', 'dove', 'python']
[x.upper() for x in strings if len(x) > 2]

# %% [markdown]
# ```python
# set_comp = {expr for value in collection if condition}
# ```

# %%
unique_lengths = {len(x) for x in strings}
unique_lengths

# %%
set(map(len, strings))

# %% [markdown]
# ```python
# dict_comp = {key_expr : value_expr for value in collection if condition}
# ```

# %%
strings_lengths = {x : len(x) for x in strings if len(x) > 1}
strings_lengths

# %%
loc_mapping = {val : index for index, val in enumerate(strings)}
loc_mapping

# %% [markdown]
# #### Nested list comprehensions

# %%
all_data = [['John', 'Emily', 'Michael', 'Mary', 'Steven'],
            ['Maria', 'Juan', 'Javier', 'Natalia', 'Pilar']]

# %%
names_of_interest = []
for names in all_data:
    enough_es = [name for name in names if name.count('e') >= 2]
    names_of_interest.extend(enough_es)
names_of_interest

# %%
result = [name for names in all_data for name in names
          if name.count('e') >= 2]
result

# %%
some_tuples = [(1, 2, 3), (4, 5, 6), (7, 8, 9)]
flattened = [x for tup in some_tuples for x in tup]
flattened

# %%
flattened = []
for tup in some_tuples:
    for x in tup:
        flattened.append(x)
flattened

# %%
[[x for x in tup] for tup in some_tuples]

# %% [markdown]
# ## Functions

# %%
def my_function(x, y, z=20):
    if z > 10:
        return x + y + z
    else:
        return x + y - z

# %%
my_function(5, 6, z=7)
# Out:
# 4

# %%
my_function(3, 7, 35)
# Out:
# 45

# %%
my_function(10, 20)

# %% [markdown]
# ### Namespaces, Scope, and Local Functions

# %%
def func():
    a = []
    for i in range(5):
        a.append(i)
a

# %%
a = []
def func():
    for i in range(5):
        a.append(i)
a

# %%
a = []
def bind_a_variable():
    global a
    for i in range(5):
        a.append(i)
bind_a_variable()
a

# %% [markdown]
# ### Returning Multiple Values

# %%
def f():
    a = 5
    b = 6
    c = 7
    return a, b, c

a, b, c = f()
print('a: {0}, b: {1}, c: {2}'.format(a, b, c))

# %%
return_value = f()
return_value

# %%
def f():
    a = 5
    b = 6
    c = 7
    return {'a' : a, 'b' : b, 'c' : c}
f()

# %% [markdown]
# ### Functions Are Objects

# %%
states = ['   Alabama ', 'Georgia!', 'Georgia', 'georgia', 'FlOrIda',
          'south   carolina##', 'West virginia?']

# %%
import re

def clean_strings(strings):
    result = []
    for value in strings:
        value = value.strip()
        value = re.sub('[!#?]', '', value)
        value = value.title()
        result.append(value)
    return result

# %%
clean_strings(states)

# %%
def remove_punctuation(value):
    return re.sub('[!#?]', '', value)

clean_ops = [str.strip, remove_punctuation, str.title]

def clean_strings(strings, ops):
    result = []
    for value in strings:
        for function in ops:
            value = function(value)
        result.append(value)
    return result

# %%
clean_strings(states, clean_ops)

# %%
for x in map(remove_punctuation, states):
    print(x)

# %% [markdown]
# ### Anonymous (Lambda) Functions

# %%
def short_function(x):
    return x * 2

equiv_anon = lambda x: x * 2

# %%
short_function(5)

# %%
equiv_anon(5)

# %%
def apply_to_list(some_list, f):
    return [f(x) for x in some_list]

ints = [4, 0, 1, 5, 6]
apply_to_list(ints, lambda x: x * 2)

# %%
strings = ['foo', 'card', 'bar', 'aaaa', 'abab']

# %%
strings.sort(key=lambda x: len(set(list(x))))
strings

# %% [markdown]
# #### itertools module

# %%
import itertools
first_letter = lambda x: x[0]
names = ['Alan', 'Adam', 'Wes', 'Will', 'Albert', 'Steven']
for letter, names in itertools.groupby(names, first_letter):
    print(letter, ':', list(names)) # names is a generator
